# %%
import os
import shutil
from pathlib import Path
import glob
import json
from datasets import load_dataset

# Define paths
data_dir = Path("/Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data")
text_dir = data_dir / "text"
imgs_all_dir = data_dir / "imgs_all"
imgs_dir = data_dir / "imgs"

# Create imgs directory if it doesn't exist
imgs_dir.mkdir(exist_ok=True)

# Process each text file
for text_file in text_dir.glob("*.txt"):
    # Get base name and convert to image name
    base_name = text_file.stem
    image_name = f"{base_name.split('_prompt')[0]}.jpg"
    
    # Source and destination paths for the image
    src_path = imgs_all_dir / image_name
    dst_path = imgs_dir / image_name
    
    # Copy the image if it exists
    if src_path.exists():
        shutil.copy2(src_path, dst_path)
        print(f"Copied {image_name} to {imgs_dir}")
    else:
        print(f"Warning: {image_name} not found in {imgs_all_dir}")

print("Image copying process completed.")
print(f"Total images in imgs_all: {len(os.listdir(imgs_all_dir))}")
print(f"Total text files: {len(os.listdir(text_dir))}")
print(f"Images in subset: {len(os.listdir(imgs_dir))}")
# Out:
# Copied 139_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 250_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 327_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 183_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 84_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 447_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 530_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 384_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 172_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 75_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 27_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 120_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 249_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 249_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 120_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 27_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 75_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 172_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 384_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 530_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 447_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 84_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 183_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 327_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 250_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 139_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 250_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 139_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 327_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 183_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 84_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 447_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 530_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 384_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 172_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 75_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 27_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 249_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 120_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 120_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 249_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 27_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 75_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 172_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 384_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 530_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 447_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 84_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 183_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 327_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 139_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 250_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 125_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 369_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 70_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 98_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 69_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 442_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 186_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 207_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 398_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 370_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 255_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 410_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 410_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 255_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 370_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 398_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 207_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 186_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 442_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 69_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 98_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 70_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 369_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 125_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 125_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 369_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 98_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 70_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 442_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 69_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 186_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 207_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 370_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 398_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 255_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 410_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 410_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 255_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 398_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 370_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 207_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 186_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 69_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 442_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 70_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 98_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 369_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 125_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 37_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 259_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 130_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 162_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 65_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 394_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 365_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 520_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 193_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 212_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 94_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 337_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 405_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 405_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 337_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 94_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 212_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 193_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 520_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 365_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 394_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 65_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 162_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 130_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 259_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 37_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 37_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 130_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 259_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 162_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 65_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 394_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 365_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 520_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 193_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 212_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 94_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 337_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 405_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 405_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 337_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 94_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 212_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 193_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 520_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 365_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 394_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 65_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 162_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 259_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 130_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 37_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 332_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 245_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 400_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 525_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 91_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 452_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 79_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 88_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 167_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 379_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 391_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 419_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 32_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 32_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 419_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 391_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 379_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 167_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 88_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 79_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 452_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 91_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 525_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 400_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 245_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 332_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 332_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 245_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 400_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 525_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 79_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 91_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 452_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 88_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 167_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 391_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 379_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 32_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 419_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 419_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 32_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 379_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 391_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 167_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 88_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 452_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 91_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 79_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 525_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 400_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 245_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 332_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 300_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 277_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 19_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 432_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 517_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 488_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 460_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 225_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 155_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 286_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 319_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 319_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 286_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 155_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 225_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 460_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 488_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 517_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 432_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 19_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 277_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 300_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 300_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 277_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 432_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 19_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 517_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 460_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 488_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 225_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 491_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 155_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 286_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 319_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 319_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 286_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 155_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 491_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 225_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 488_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 460_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 517_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 19_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 432_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 277_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 300_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 283_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 102_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 150_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 239_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 57_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 494_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 8_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 357_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 512_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 149_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 220_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 437_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 437_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 220_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 149_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 512_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 357_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 8_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 494_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 57_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 239_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 150_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 102_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 283_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 283_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 102_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 239_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 150_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 57_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 494_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 8_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 357_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 512_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 220_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 149_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 437_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 437_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 149_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 220_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 512_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 357_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 8_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 494_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 57_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 150_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 239_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 102_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 283_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 309_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 296_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 117_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 469_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 42_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 481_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 470_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 235_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 342_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 422_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 422_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 342_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 235_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 470_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 481_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 42_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 469_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 117_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 296_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 309_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 309_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 296_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 117_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 42_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 481_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 469_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 470_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 235_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 342_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 422_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 422_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 342_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 235_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 470_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 469_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 481_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 42_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 117_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 296_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 309_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 262_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 315_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 475_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 347_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 1_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 502_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 229_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 140_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 47_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 15_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 112_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 112_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 15_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 47_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 140_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 229_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 1_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 502_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 347_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 475_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 315_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 262_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 262_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 315_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 475_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 347_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 502_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 1_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 140_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 229_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 47_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 15_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 112_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 112_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 15_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 47_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 229_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 140_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 502_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 1_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 347_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 475_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 315_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 262_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Image copying process completed.
# Total images in imgs_all: 2141
# Total text files: 383
# Images in subset: 96

# %%
def create_metadata_file(data_dir, output_file):
    image_files = glob.glob(os.path.join(data_dir, "imgs", "*.jpg"))
    metadata = []

    for image_file in image_files:
        base_name = os.path.basename(image_file)
        name_without_ext = base_name.split('.')[0]
        text_files = glob.glob(os.path.join(data_dir, "text", f"{name_without_ext}_prompt*.txt"))
        
        for text_file in text_files:
            with open(text_file, 'r') as f:
                caption = f.read().strip()
            
            metadata.append({
                "file_name": f"imgs/{base_name}",
                "text": caption
            })

    with open(output_file, 'w') as f:
        for item in metadata:
            f.write(json.dumps(item) + '\n')

# Create metadata file
data_dir = "/Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/"
metadata_file = os.path.join(data_dir, "metadata.jsonl")
create_metadata_file(data_dir, metadata_file)

# %%
data_files = {}
train_data_dir = data_dir
if train_data_dir is not None:
    data_files["train"] = os.path.join(train_data_dir, "**")
dataset = load_dataset(
    "imagefolder",
    data_files=data_files,
)
# Out:
# Downloading data: 100%|██████████| 40/40 [00:00<00:00, 605675.67files/s]
# Generating train split: 10 examples [00:00, 459.77 examples/s]

# %%
# Load the dataset using ImageFolder
#dataset = load_dataset("imagefolder", data_dir=data_dir, split="train")

# Print basic information about the dataset
print(f"Dataset size: {len(dataset)}")
print(f"Features: {dataset['train'].features}")

# Display the first few examples
print("\nFirst few examples:")
for i, example in enumerate(dataset['train']):
    print(f"\nExample {i+1}:")
    print(example)
# Out:
# Dataset size: 1
# Features: {'image': Image(mode=None, decode=True, id=None), 'text': Value(dtype='string', id=None)}
#
# First few examples:
#
# Example 1:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x691 at 0x158290410>, 'text': 'The facade features white stucco walls, red tile roofing, and beige decorative balustrades. There are exterior sconces and patterned railings enhancing the visual appeal.'}
#
# Example 2:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=916x600 at 0x17FA8E9D0>, 'text': 'A single-story house with a partial stone facade, a prominent entryway, and a landscaped front yard featuring a U.S. flagpole and various desert plants.'}
#
# Example 3:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=767x574 at 0x17F68C290>, 'text': 'The facade features red and white brick, beige vertical siding, dark green trim, and a tiled roof. Decorative plants and potted flowers adorn the brick staircase entry.'}
#
# Example 4:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x424 at 0x158291A90>, 'text': 'Charming two-story Craftsman home with gable roofs, stone accents, spacious lawn, welcoming front porch, and brick-paver steps. Features open-plan design and elegant shutters, blending comfort with curb appeal.'}
#
# Example 5:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427 at 0x15822C990>, 'text': 'Modern two-story home with a charming porch, spacious dual garages, stucco exterior, tiled roof, and manicured lawn. Highlights include layered roofline, prominent eaves, and inviting outdoor veranda.'}
#
# Example 6:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x375 at 0x15822C3D0>, 'text': 'This single-story home features a multi-car garage, a covered front porch, and a well-manicured lawn, all set against a scenic mountainous backdrop.'}
#
# Example 7:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=957x635 at 0x17FA473D0>, 'text': 'The house is single-story with a tiled roof. It features a front yard with landscaped shrubs and a boundary fence for privacy. There are no visible balconies or terraces.'}
#
# Example 8:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1020x645 at 0x17FA45ED0>, 'text': 'The house features a California Ranch style characterized by stucco walls, gable roofs with exposed beams, large garage door, and an open, single-story layout.'}
#
# Example 9:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=580x436 at 0x17FA466D0>, 'text': 'This two-story brick house features large arched windows, a three-car garage, and a prominent front door, with an attractive gable roof design and well-maintained landscaping.'}
#
# Example 10:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x680 at 0x17FA44D90>, 'text': 'This is a two-story house with a tiled roof, prominent front gable, large windows, and an attached garage, featuring a clean, charming exterior.'}
