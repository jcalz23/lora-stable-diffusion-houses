# %%
import os
import shutil
from pathlib import Path
import glob
import json
from datasets import load_dataset

# Define paths
data_dir = Path("/Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data")
text_dir = data_dir / "text"
imgs_all_dir = data_dir / "imgs_all"
imgs_dir = data_dir / "imgs"

# Create imgs directory if it doesn't exist
imgs_dir.mkdir(exist_ok=True)

# Process each text file
for text_file in text_dir.glob("*.txt"):
    # Get base name and convert to image name
    base_name = text_file.stem
    image_name = f"{base_name.split('_prompt')[0]}.jpg"
    
    # Source and destination paths for the image
    src_path = imgs_all_dir / image_name
    dst_path = imgs_dir / image_name
    
    # Copy the image if it exists
    if src_path.exists():
        shutil.copy2(src_path, dst_path)
        print(f"Copied {image_name} to {imgs_dir}")
    else:
        print(f"Warning: {image_name} not found in {imgs_all_dir}")

print("Image copying process completed.")
print(f"Total images in imgs_all: {len(os.listdir(imgs_all_dir))}")
print(f"Total text files: {len(os.listdir(text_dir))}")
print(f"Images in subset: {len(os.listdir(imgs_dir))}")
# Out:
# Copied 415_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 168_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 528_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 201_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 180_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 87_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 139_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 444_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 250_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 385_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 122_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 376_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 74_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 327_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 173_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 25_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 533_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 416_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 202_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 183_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 84_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 447_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 253_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 386_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 375_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 121_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 77_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 248_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 170_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 324_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 198_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 219_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 26_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 530_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 86_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 445_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 138_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 251_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 384_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 169_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 414_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 200_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 529_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 181_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 172_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 326_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 532_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 24_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 377_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 123_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 75_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 85_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 446_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 252_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 387_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 417_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 203_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 182_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 325_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 171_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 199_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 531_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 27_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 218_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 120_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 374_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 249_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 76_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 76_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 249_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 374_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 120_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 218_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 531_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 27_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 199_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 171_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 325_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 182_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 203_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 417_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 387_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 252_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 446_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 85_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 75_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 123_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 377_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 532_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 24_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 326_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 172_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 181_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 529_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 200_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 169_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 414_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 384_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 251_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 445_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 138_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 86_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 26_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 530_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 219_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 198_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 324_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 170_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 248_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 77_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 121_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 375_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 386_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 253_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 447_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 84_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 183_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 202_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 416_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 25_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 533_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 173_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 327_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 74_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 376_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 122_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 385_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 250_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 139_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 444_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 87_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 180_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 201_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 528_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 415_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 168_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 528_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 201_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 180_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 168_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 415_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 250_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 385_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 87_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 444_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 139_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 74_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 122_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 376_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 533_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 25_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 327_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 173_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 202_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 183_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 416_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 253_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 386_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 84_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 447_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 77_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 248_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 375_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 121_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 198_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 219_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 530_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 26_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 170_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 324_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 251_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 384_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 86_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 138_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 445_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 200_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 529_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 181_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 414_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 169_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 24_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 532_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 172_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 326_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 75_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 377_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 123_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 252_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 387_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 85_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 446_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 203_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 182_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 417_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 199_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 27_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 531_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 218_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 325_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 171_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 249_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 76_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 120_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 374_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 374_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 120_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 76_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 249_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 171_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 325_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 218_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 27_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 531_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 199_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 417_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 182_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 203_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 446_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 85_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 387_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 252_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 123_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 377_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 75_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 326_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 172_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 24_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 532_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 414_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 169_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 181_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 529_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 200_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 138_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 445_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 86_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 384_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 251_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 324_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 170_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 530_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 26_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 219_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 198_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 121_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 375_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 248_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 77_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 447_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 84_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 386_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 253_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 416_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 183_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 202_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 173_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 327_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 533_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 25_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 376_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 122_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 74_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 444_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 139_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 87_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 385_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 250_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 168_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 415_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 180_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 201_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 528_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 187_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 206_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 39_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 412_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 382_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 68_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 257_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 443_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 80_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 73_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 399_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 371_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 458_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 125_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 22_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 534_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 174_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 409_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 320_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 184_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 205_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 338_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 411_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 381_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 254_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 440_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 369_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 83_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 70_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 98_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 126_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 372_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 21_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 323_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 177_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 383_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 256_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 69_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 442_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 81_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 186_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 38_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 207_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 413_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 535_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 23_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 321_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 408_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 175_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 72_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 398_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 124_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 459_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 370_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 380_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 255_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 368_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 441_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 82_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 185_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 204_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 410_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 339_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 20_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 176_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 322_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 71_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 99_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 373_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 127_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 127_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 373_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 99_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 71_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 322_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 176_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 20_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 339_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 410_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 204_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 185_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 82_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 441_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 368_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 255_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 380_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 370_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 124_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 459_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 398_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 72_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 408_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 175_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 321_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 535_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 23_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 413_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 207_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 38_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 186_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 81_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 442_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 69_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 256_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 383_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 177_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 323_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 21_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 372_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 126_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 98_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 70_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 83_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 369_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 440_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 254_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 381_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 411_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 338_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 205_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 184_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 320_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 174_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 409_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 22_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 534_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 458_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 125_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 371_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 399_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 73_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 80_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 443_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 257_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 68_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 382_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 412_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 39_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 206_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 187_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 412_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 187_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 206_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 39_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 443_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 80_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 382_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 68_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 257_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 371_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 125_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 458_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 73_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 399_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 409_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 174_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 320_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 534_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 22_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 338_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 411_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 184_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 205_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 440_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 369_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 83_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 381_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 254_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 98_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 126_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 372_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 70_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 323_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 177_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 21_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 442_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 81_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 383_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 256_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 69_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 413_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 186_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 38_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 207_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 321_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 175_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 408_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 23_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 535_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 459_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 124_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 370_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 72_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 398_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 368_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 441_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 82_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 380_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 255_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 410_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 339_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 185_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 204_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 176_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 322_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 20_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 99_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 373_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 127_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 71_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 71_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 127_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 373_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 99_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 20_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 322_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 176_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 204_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 185_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 339_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 410_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 255_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 380_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 82_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 441_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 368_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 398_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 72_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 370_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 459_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 124_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 23_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 535_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 175_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# ...
# Copied 316_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 1_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 502_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 14_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 292_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 347_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 113_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 45_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 486_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 475_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 108_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 289_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 261_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 159_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 424_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 230_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 519_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 315_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 141_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 2_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 501_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 17_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 228_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 291_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 110_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 344_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 279_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 46_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 485_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 476_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 262_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 427_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 233_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 427_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 233_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 476_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 262_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 344_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 110_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 291_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 485_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 46_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 279_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 141_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 315_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 228_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 17_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 501_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 2_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 424_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 159_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 519_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 230_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 289_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 108_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 475_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 261_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 113_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 347_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 292_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 486_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 45_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 316_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 142_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 14_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 502_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 1_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 477_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 263_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 426_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 232_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 314_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 140_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 3_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 500_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 16_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 229_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 111_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 345_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 290_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 484_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 278_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 47_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 288_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 474_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 109_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 260_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 158_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 425_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 231_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 518_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 143_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 317_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 503_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 15_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 346_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 112_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 293_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 487_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 44_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 44_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 487_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 293_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 112_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 346_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 503_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 15_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 317_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 143_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 518_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 231_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 158_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 425_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 260_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 474_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 109_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 288_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 47_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 278_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 484_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 290_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 345_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 111_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 3_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 229_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 500_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 16_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 140_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 314_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 232_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 426_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 263_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 477_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 14_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 502_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 1_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 142_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 316_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 45_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 486_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 292_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 347_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 113_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 261_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 108_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 475_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 289_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 230_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 519_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 424_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 159_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 17_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 501_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 228_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 2_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 315_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 141_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 279_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 46_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 485_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 291_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 110_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 344_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 262_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 476_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 233_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Copied 427_frontal.jpg to /Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/imgs
# Image copying process completed.
# Total images in imgs_all: 2141
# Total text files: 2140
# Images in subset: 535

# %%
def create_metadata_file(data_dir, output_file):
    image_files = glob.glob(os.path.join(data_dir, "imgs", "*.jpg"))
    metadata = []

    for image_file in image_files:
        base_name = os.path.basename(image_file)
        name_without_ext = base_name.split('.')[0]
        text_files = glob.glob(os.path.join(data_dir, "text", f"{name_without_ext}_prompt*.txt"))
        
        for text_file in text_files:
            with open(text_file, 'r') as f:
                caption = f.read().strip()
            
            metadata.append({
                "file_name": f"imgs/{base_name}",
                "text": caption
            })

    with open(output_file, 'w') as f:
        for item in metadata:
            f.write(json.dumps(item) + '\n')

# Create metadata file
data_dir = "/Users/johncalzaretta/Desktop/lora-stable-diffusion-houses/data/"
metadata_file = os.path.join(data_dir, "metadata.jsonl")
create_metadata_file(data_dir, metadata_file)

# %%
data_files = {}
train_data_dir = data_dir
if train_data_dir is not None:
    data_files["train"] = os.path.join(train_data_dir, "**")
dataset = load_dataset(
    "imagefolder",
    data_files=data_files,
)
# Out:
# Downloading data: 100%|██████████| 536/536 [00:00<00:00, 1418389.24files/s]
# Downloading data: 100%|██████████| 2140/2140 [00:00<00:00, 178211.70files/s]
# Generating train split: 535 examples [00:00, 14978.06 examples/s]

# %%
# Load the dataset using ImageFolder
#dataset = load_dataset("imagefolder", data_dir=data_dir, split="train")

# Print basic information about the dataset
print(f"Dataset size: {len(dataset)}")
print(f"Features: {dataset['train'].features}")

# Display the first few examples
print("\nFirst few examples:")
for i, example in enumerate(dataset['train']):
    print(f"\nExample {i+1}:")
    print(example)
# Out:
# Dataset size: 1
# Features: {'image': Image(mode=None, decode=True, id=None), 'text': Value(dtype='string', id=None)}
#
# First few examples:
#
# Example 1:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x683 at 0x17FB7BDD0>, 'text': 'This modern two-story home showcases a three-car garage, expansive windows, contemporary architecture, manicured palm trees, and picturesque sunset views, blending comfort with stunning aesthetics for truly luxurious living.'}
#
# Example 2:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x677 at 0x1586D9E10>, 'text': 'This house features a modern ranch architectural style, with a stucco exterior, gable roof, and large windows for ample natural light.'}
#
# Example 3:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x691 at 0x1586D8190>, 'text': 'The facade features white stucco walls, red tile roofing, and beige decorative balustrades. There are exterior sconces and patterned railings enhancing the visual appeal.'}
#
# Example 4:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x853 at 0x1586D8E90>, 'text': 'The house features two stories, with balconies, a stone exterior, lush landscaping, and multiple chimneys, creating a unique and appealing architectural presence.'}
#
# Example 5:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x683 at 0x1586DB5D0>, 'text': 'Single-story home with mid-century modern influences, featuring large glass windows, overhanging eaves, and a minimalist, functional design emphasizing horizontal lines and integration with nature.'}
#
# Example 6:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x1586DA150>, 'text': 'Charming ranch-style home with an expansive single-story layout, featuring large windows, a manicured lawn, mature landscaping, and unique gabled roofs. The property exudes a timeless, welcoming ambiance.'}
#
# Example 7:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x534 at 0x17F828D90>, 'text': 'Single-story house with a tiled roof, three-car garage, and a spacious backyard with a stone patio and outdoor seating area. Features include a veranda and landscaped garden.'}
#
# Example 8:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1020x680 at 0x17F829910>, 'text': 'The facade features grey siding with red brick accents, large windows, white trim, a sloped shingle roof, and minimal decorative elements or lighting fixtures.'}
#
# Example 9:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x683 at 0x17F82A590>, 'text': 'The house is a single-story structure featuring a three-car garage, a spacious driveway, and landscaped surroundings with views of mountainous terrain.'}
#
# Example 10:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x576 at 0x17F82BD50>, 'text': 'The facade features cream stucco walls, gray roof tiles, arched windows and doors, and wall-mounted lighting fixtures. Simple lines and textures create a clean, Mediterranean-inspired aesthetic.'}
#
# Example 11:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=900x600 at 0x17F829310>, 'text': 'Single-story house with a Southwestern architectural style, featuring an arched entryway, a spacious garage, desert landscaping, and small, decorative windows.'}
#
# Example 12:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=700x467 at 0x17F82B250>, 'text': 'Stucco facade in warm earth tones, with recessed lighting fixtures under eaves and around windows. Decorative stone border around perimeter close to garden with lush grass.'}
#
# Example 13:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x683 at 0x17F82A590>, 'text': 'The house is a two-story structure featuring large windows, multiple chimneys, and an extensive pergola-covered patio area. It is situated on a landscaped hill.'}
#
# Example 14:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x846 at 0x17F82B110>, 'text': 'This Mediterranean-style home features a four-car garage, lush landscaping, large windows, and open layout. Unique tiled roof and expansive driveway complete this elegant, sophisticated property.'}
#
# Example 15:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=999x666 at 0x17F829110>, 'text': 'The house features a contemporary suburban style with stucco finishes, stone accents, a gabled roof, and large garage doors.'}
#
# Example 16:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x683 at 0x17F829250>, 'text': 'This single-story house features a stone and stucco exterior, gable roofs, and a central entryway, with a landscaped garden and pathway leading to the front door.'}
#
# Example 17:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x682 at 0x17F82BD50>, 'text': 'The facade uses textured green-gray brick with a white trim. A red brick chimney adds contrast. Minimalist design, no visible decorative elements or lighting fixtures.'}
#
# Example 18:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x680 at 0x17F82AFD0>, 'text': 'Spanish Mediterranean style featuring red tile roof, stucco walls, arched windows, wooden double doors, and lush landscaping with palm trees and vibrant flowers.'}
#
# Example 19:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x683 at 0x17F82A390>, 'text': 'This cozy Ranch-style home features a two-car garage, inviting front porch, vibrant greenery, and a scenic backdrop of mountains, offering both comfort and picturesque views.'}
#
# Example 20:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x683 at 0x17F82AB10>, 'text': 'This house features a blend of Mid-century modern and Ranch styles, characterized by its low-pitched roof, asymmetrical design, and integrated garage.'}
#
# Example 21:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x683 at 0x17F829B50>, 'text': 'This suburban home features a modern architectural style with two stories, a spacious two-car garage, lush garden landscaping, and privacy-enhancing mature trees, creating a charming and tranquil retreat.'}
#
# Example 22:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=900x600 at 0x17F82AD10>, 'text': 'The facade features terracotta and stone materials, earthy beige tones, arched windows, and tile roofing. Decorative lantern-style lighting fixtures highlight entranceway pillars. Desert landscaping complements aesthetics.'}
#
# Example 23:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x681 at 0x17F82B9D0>, 'text': 'The house features a simple, mid-century modern architectural style with a low-pitched roof, wide eaves, horizontal lines, and large windows. The exterior is minimalistic and unadorned.'}
#
# Example 24:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x682 at 0x17F82A290>, 'text': 'This charming home features a rustic architectural style, single-story layout, expansive driveway, vibrant cacti garden, and breathtaking panoramic mountain views, creating a serene and unique living experience.'}
#
# Example 25:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x682 at 0x17F82AD90>, 'text': 'Single-story house with a pitched roof, wide front windows, attached garage, and garden area; emphasizes a cozy, straightforward design without balconies or verandas.'}
#
# Example 26:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x17F82B390>, 'text': 'The facade features white brick with green accents, a red tile roof, wood-framed doors, and decorative lighting fixtures. Pathway bordered by bricks and surrounded by landscaped greenery.'}
#
# Example 27:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x680 at 0x17F8292D0>, 'text': 'Spanish-style home with terracotta roof tiles, arched doorway, stucco exterior, symmetrical layout, vibrant garden, and a welcoming veranda creating a charming, unique curb appeal.'}
#
# Example 28:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x17FB1BB10>, 'text': 'The house showcases a Mediterranean architectural style with stucco walls, red-tiled roof, arched windows, and columns, complemented by a spacious balcony and wrought iron details.'}
#
# Example 29:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427 at 0x17FB1A110>, 'text': 'The facade features cream stucco walls, a red-tiled roof, and decorative wrought-iron doors. The entryway has arched columns with stone steps and a paved walkway.'}
#
# Example 30:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x479 at 0x17FB19010>, 'text': 'Two-story house with a three-car garage, featuring a combination of stucco and brick exterior. There is a partially enclosed entry patio and no visible balconies or verandas.'}
#
# Example 31:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427 at 0x17FB1A050>, 'text': 'The facade features beige stucco walls, red roof tiles, and a large black-framed window. A white door with a small light fixture is present.'}
#
# Example 32:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x422 at 0x17FB19750>, 'text': 'Two-story house with three-car garage, white picket fence, front veranda, and dormer windows on the second floor.'}
#
# Example 33:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=898x600 at 0x17FB1A110>, 'text': 'The house showcases a Craftsman-inspired architectural style with a low-pitched roof, covered porch, stone accents, and a blend of rustic and modern details.'}
#
# Example 34:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x426 at 0x17FB1A7D0>, 'text': 'This house appears to be a single-story structure with a gable roof, compact layout, and functional entrance, looking like a pool house or utility building rather than a full dwelling.'}
#
# Example 35:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x383 at 0x17FB1AA10>, 'text': 'The facade features beige and light brown siding, a stone accent wall, white-framed windows, dark gray garage doors, and palm landscaping. No visible decorative elements or lighting fixtures.'}
#
# Example 36:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x371 at 0x17FB1A110>, 'text': 'The house features a Mid-Century Modern architectural style with large windows, flat planes, and integration with nature, evidenced by surrounding trees and spacious balconies.'}
#
# Example 37:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x17FB19810>, 'text': 'Charming single-story Craftsman home with three-car garage, featuring stucco exterior, gable roof, lush front yard landscaping, and a spacious, patterned concrete driveway.'}
#
# Example 38:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427 at 0x17FB1A050>, 'text': 'The facade features beige stucco walls, white trim, and a flat roof. Decorative elements include a black wall-mounted lantern and a sliding glass door. Green hedges line the walkway.'}
#
# Example 39:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x17FB1AA10>, 'text': "The house has two stories, featuring balconies and a terrace. There's a communal swimming pool in the foreground, enhancing the property's recreational amenities."}
#
# Example 40:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427 at 0x17FB1A550>, 'text': 'Mediterranean-inspired home with stucco exterior, terracotta roof, and symmetrical windows. Featuring an inviting arched entry, lush landscaping, palm trees, and vibrant blue shutters for a charming, unique appeal.'}
#
# Example 41:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x355 at 0x17FB19D50>, 'text': 'A modern suburban home featuring horizontal siding, large multi-pane windows, a gabled roof, and an attached three-car garage with paved driveway.'}
#
# Example 42:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427 at 0x17FB19810>, 'text': 'Modern Mediterranean-style condo features stucco walls, tiled roofing, side staircase, and charming balcony. Surrounded by lush landscaping, it boasts thoughtful design and cozy outdoor spaces, perfect for contemporary living.'}
#
# Example 43:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427 at 0x17FB1ABD0>, 'text': 'The house features a Mediterranean architectural style with stucco walls, red-tiled roofs, and a central courtyard fountain, emphasizing open-air and outdoor living areas.'}
#
# Example 44:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x600 at 0x17FB1A550>, 'text': 'Modern Southwestern-style home features a flat roof, stucco exterior, spacious three-car garage, desert landscaping, and unique angular architecture, epitomizing efficient design and harmonious natural integration.'}
#
# Example 45:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427 at 0x15828A310>, 'text': 'Single-story house featuring a straightforward structure with a well-maintained lawn, an attached garage, and pruned trees lining the driveway.'}
#
# Example 46:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427 at 0x17F828C10>, 'text': 'The facade features beige vertical siding, white trim, a brown shingle roof, and wooden walkways. Decorative elements include a red door, white porch pillars, and a vintage-style exterior light.'}
#
# Example 47:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x428 at 0x158288650>, 'text': 'The house features a Mediterranean-style architecture with stucco walls, red tile roof, arched windows and lush tropical landscaping.'}
#
# Example 48:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427 at 0x15828A310>, 'text': 'Modern single-story home with minimalistic clean lines, featuring an attached two-car garage, manicured front yard, and gated entrance, providing both privacy and aesthetic appeal. Thriving greenery enhances its charm.'}
#
# Example 49:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x158288BD0>, 'text': 'The facade features yellow siding with white trim and a red-tiled roof. Decorative elements include black lantern-style lighting fixtures and an arched front door with sidelights.'}
#
# Example 50:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x158288510>, 'text': 'This is a two-story house featuring a dual garage, arched entryway, two front windows with shutters, and a distinctive small decorative balcony above the garage.'}
#
# Example 51:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=494x480 at 0x15828A310>, 'text': 'This Mediterranean-style home features a two-story layout with stucco walls, red-tiled roof, arched entryway, attached two-car garage, and a lush front yard, embodying elegant, timeless appeal.'}
#
# Example 52:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x448 at 0x158288BD0>, 'text': 'The house features Mediterranean architectural style with stucco walls, clay tile roof, arched entryways, and a manicured garden, reflecting Spanish and Italian influences.'}
#
# Example 53:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=394x480 at 0x158288510>, 'text': 'This two-story, modern townhouse features a gabled roof, attached garage, large front windows, and a landscaped driveway, offering contemporary aesthetics and functional outdoor space.'}
#
# Example 54:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x426 at 0x1585194D0>, 'text': 'The house features a Mediterranean Revival style, characterized by stucco walls, tiled roofs, arched entryways, and a focus on blending with natural surroundings.'}
#
# Example 55:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x523 at 0x15851A990>, 'text': 'The facade features earthy-orange stucco, stone accents, and clay roof tiles. Decorative stone columns frame the entrance, with subtle lighting fixtures. Bushes and desert plants complement the exterior.'}
#
# Example 56:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x426 at 0x1585194D0>, 'text': 'The house exhibits a contemporary Mediterranean style, characterized by a stucco exterior, arched windows, and a clay-tile roof, surrounded by lush landscaping and palm trees.'}
#
# Example 57:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x418 at 0x15851A810>, 'text': 'Mediterranean-style home, featuring a stucco exterior, tile roof, lush landscaping, and attached two-car garage. Spacious layout with prominent balconies and large windows, offering abundant natural light and curb appeal.'}
#
# Example 58:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x767 at 0x15851B510>, 'text': 'This single-story house features a modest exterior with multiple windows, a flat roof, and an outdoor patio area. No balconies, terraces, or verandas are visible.'}
#
# Example 59:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x15851B650>, 'text': 'The facade features white paneling with purple trim, textured shutters, minimalistic landscaping, and metal awnings over windows. Simple, understated design with no decorative elements or visible lighting fixtures.'}
#
# Example 60:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x576 at 0x1585182D0>, 'text': "Charming cottage-style home featuring a cozy front porch, spacious rooms, and a large, lush yard. Nestled in a serene, wooded area, it's perfect for nature enthusiasts and tranquility seekers."}
#
# Example 61:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=637x460 at 0x158519610>, 'text': 'The house features a Ranch-style architecture with a single-story layout, horizontal lines, and an open patio, reflecting mid-20th-century American suburban design.'}
#
# Example 62:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x158519ED0>, 'text': 'The facade features light gray stucco with white trim, a decorative lantern-style light fixture, and a white door. Simple black railing enhances the front steps and entryway.'}
#
# Example 63:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x682 at 0x15851BE50>, 'text': 'Single-story house with a spacious front deck, large windows, and a covered entryway. The deck area features ample space for outdoor furniture and potted plants.'}
#
# Example 64:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x158518090>, 'text': 'The facade features beige wooden siding, cream trim, and a maroon door. Decorative cross beams adorn the gables. Single lantern-style lighting fixture beside the beige garage door.'}
#
# Example 65:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x537 at 0x158519ED0>, 'text': 'Single-story house with a green exterior, covered front porch, and surrounded by trees. Features a simple rectangular layout and an expansive yard.'}
#
# Example 66:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=916x600 at 0x15851B7D0>, 'text': 'A single-story house with a partial stone facade, a prominent entryway, and a landscaped front yard featuring a U.S. flagpole and various desert plants.'}
#
# Example 67:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=420x315 at 0x158519D90>, 'text': 'The facade features beige stucco walls, a dark-toned roof, wooden double doors with glass inserts, and minimalistic black lighting fixtures. Some greenery and decorative stone accents enhance the exterior.'}
#
# Example 68:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x683 at 0x158519410>, 'text': 'Single-story house with a gable roof, featuring an attached three-car garage and a small porch entry. Lush landscaping enhances the front yard.'}
#
# Example 69:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x682 at 0x158519310>, 'text': 'Charming Ranch-style home with clean lines, featuring a spacious garage, well-manicured lawn, mature trees, and a welcoming front porch, ideal for comfortable living and outdoor enjoyment.'}
#
# Example 70:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x158518C90>, 'text': 'The house features a contemporary suburban style with simple lines, neutral tones, gable roofs, and minimal ornamental detailing. The landscaping is xeriscaped with a curved pathway.'}
#
# Example 71:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=765x511 at 0x158519D90>, 'text': 'Single-story house with a gable roof, an attached three-car garage, and a porch in a landscaped front yard.'}
#
# Example 72:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x480 at 0x158519ED0>, 'text': 'The facade features beige stucco, a gray shingled roof, white trim, and arched windows. Decorative elements include dormers and a central peaked gable. Minimalistic lighting fixtures are present.'}
#
# Example 73:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=767x510 at 0x15851A810>, 'text': 'The house showcases a contemporary ranch style with a single-story layout, low-pitched roof, and an emphasis on outdoor living spaces.'}
#
# Example 74:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=767x431 at 0x15851B710>, 'text': 'This charming ranch-style home features a spacious deck, large windows, and a scenic yard with vibrant bushes. Its inviting open layout is perfect for outdoor entertaining and relaxation.'}
#
# Example 75:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=767x511 at 0x158519D90>, 'text': 'The house features a ranch-style architecture with a single-story layout, a low-pitched roof, an attached garage, and a simple, rectangular design.'}
#
# Example 76:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=767x507 at 0x158518490>, 'text': 'Mediterranean-style home with stone façade, arched entryway, and terra-cotta tiled roof. Features three-car garage, spacious driveway, lush landscaping, and distinctive architectural details.'}
#
# Example 77:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=900x600 at 0x158519F90>, 'text': 'This home features a Mediterranean architectural style with a three-car garage, stone accents, arched entryway, desert landscaping, and terracotta roof tiles, providing a charming and unique aesthetic.'}
#
# Example 78:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=641x368 at 0x15851A850>, 'text': 'Contemporary single-story home with a three-car garage, manicured landscaping, and a spacious driveway. The house features a gabled roof, lush greenery, and thoughtfully designed pathways, providing both elegance and functionality.'}
#
# Example 79:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=767x511 at 0x15851BAD0>, 'text': 'This house features a Mediterranean-inspired architectural style with stucco walls, tiled roof, arched doorways, and ornamental details, blending luxury with classical European elements.'}
#
# Example 80:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=767x574 at 0x158519E10>, 'text': 'The facade features red and white brick, beige vertical siding, dark green trim, and a tiled roof. Decorative plants and potted flowers adorn the brick staircase entry.'}
#
# Example 81:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=767x575 at 0x158519D90>, 'text': 'Two-story house with stone facade, prominent two-car garage, manicured landscaping, and grand entrance. Features gabled rooflines and lush greenery, providing an elegant and inviting appearance.'}
#
# Example 82:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x683 at 0x15851B7D0>, 'text': 'The house features a Craftsman architectural style, characterized by a low-pitched roof, exposed rafters, a covered porch with square columns, and a mix of materials.'}
#
# Example 83:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x770 at 0x15851A5D0>, 'text': 'Charming bungalow-style home featuring a covered porch, stone column accents, beautifully landscaped front yard, and inviting steps nestled in a quiet neighborhood.'}
#
# Example 84:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x534 at 0x158518090>, 'text': 'The house is a two-story structure with a distinct front balcony, featuring a wood-panel exterior and "Park Webster" signage.'}
#
# Example 85:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x684 at 0x15851A210>, 'text': 'The facade features light beige siding with dark green trim, wooden texture, and a single light fixture above the entrance. Decorative elements include white handrails and a screened front door.'}
#
# Example 86:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x679 at 0x15851B150>, 'text': 'This single-story house features a front porch with a railing, steps leading up to it, and distinct triangular roof gables, adding to its charming architectural design.'}
#
# Example 87:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=900x600 at 0x1585194D0>, 'text': 'The facade features light grey siding with white trim, dark roof shingles, and a white picket fence. Decorative elements include front porch columns and shrubs, with no visible exterior lighting fixtures.'}
#
# Example 88:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x480 at 0x158518090>, 'text': 'The house has a Southwestern architectural style, featuring stucco walls, rounded corners, flat rooflines, and earthy colors, blending with the desert landscape.'}
#
# Example 89:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=900x600 at 0x158519610>, 'text': 'This single-story house features a prominent front porch with stone pillars, large windows, and a simple yet elegant facade with bungalow-style architectural elements.'}
#
# Example 90:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=636x423 at 0x15851A450>, 'text': 'The facade features beige stucco with brown trim, brick accents, and decorative metal balconies. Lighting fixtures are mounted on the walls, complementing the simple yet elegant style.'}
#
# Example 91:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=700x467 at 0x15851B550>, 'text': 'The house features a contemporary suburban architectural style with clean lines, stucco exterior, and a simple gabled roof, complemented by manicured landscaping and a welcoming porch.'}
#
# Example 92:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=900x600 at 0x158519310>, 'text': 'Charming cottage-style house with a pastel-blue gable roof, front porch with decorative railings, spacious yard, and quaint window trims, exuding a cozy vintage appeal.'}
#
# Example 93:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x682 at 0x162EBF690>, 'text': 'The facade uses light gray horizontal siding, a bold red door, and white trim. Decorative elements include wrought iron railings and a unique diamond-shaped window. Two wall-mounted light fixtures present.'}
#
# Example 94:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x590 at 0x16AB7FCD0>, 'text': 'This two-story house features a covered front porch and modern design elements, including large windows and a pitched roof, harmonizing contemporary and classic architecture.'}
#
# Example 95:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x784 at 0x158288BD0>, 'text': 'This Mediterranean-style home features a two-story layout, red-tiled roof, manicured lawn, modern porch, and large windows, creating a unique blend of classic elegance and contemporary comfort.'}
#
# Example 96:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x683 at 0x158288950>, 'text': 'The house features a contemporary architectural style with a combination of large windows, clean lines, flat surfaces, and an open floor plan, creating an airy, modern look.'}
#
# Example 97:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x682 at 0x158289C10>, 'text': 'Charming Craftsman bungalow featuring a tiered roof, cozy front porch with brick accents, drought-resistant landscaping, and mature shrubbery, reflecting a blend of tradition and functional elegance.'}
#
# Example 98:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=666x444 at 0x1586D9D90>, 'text': 'The house features Spanish Revival architecture, characterized by stucco walls, clay tile roof, arched doorways, and a small turret, creating a charming blend of simplicity and elegance.'}
#
# Example 99:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=630x407 at 0x1586DA150>, 'text': 'This charming Southwestern-style home features a stucco exterior, tile roof, spacious garage, lush landscaping, and inviting courtyard, blending traditional design with modern amenities for a serene desert retreat.'}
#
# Example 100:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x679 at 0x17F82A650>, 'text': 'The house exhibits a bungalow-style architecture with stucco walls, blue trim accents, and minimal ornamentation, characterized by a low-pitched roof and a simple, functional design.'}
#
# Example 101:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x662 at 0x17F828250>, 'text': 'This charming Victorian home features a turret, wraparound porch, lush landscaping, and mature trees, exuding timeless elegance and unique historical charm in a serene neighborhood.'}
#
# Example 102:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x17F82A290>, 'text': 'The house features multiple stories, a communal swimming pool, balconies, and a landscaped patio area. It has a modern design with large windows and verdant surroundings, enhancing its contemporary appeal.'}
#
# Example 103:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=900x600 at 0x17F82BAD0>, 'text': 'The facade combines cream stucco, dark trim, and stone detailing. Decorative elements include an arched wooden door and dormer windows. Subtle exterior lighting frames the entrance.'}
#
# Example 104:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x678 at 0x17F828750>, 'text': 'This charming Spanish Revival home features asymmetrical stucco façade, a cozy front porch, lush landscaping, and an attached garage, exuding unique curb appeal and a quaint residential ambiance.'}
#
# Example 105:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x682 at 0x17F82AFD0>, 'text': 'The house features Craftsman architectural style, characterized by its overhanging eaves, exposed rafters, wood shingles, prominent front porch, and double-hung windows.'}
#
# Example 106:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x17F8294D0>, 'text': 'Beige stucco facade with white trim, flat roof, and minimalistic design. Decorative elements include a secure metal gate and lush landscaping. No visible decorative lighting fixtures.'}
#
# Example 107:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x683 at 0x17FB1AD90>, 'text': 'The house is a two-story structure featuring multiple stone chimneys, expansive balconies, and lush landscaping with tropical trees.'}
#
# Example 108:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x682 at 0x17FB185D0>, 'text': 'The facade features neutral-colored siding, large windows, and balconies. Decorative elements include potted plants and railings. Warm external lighting enhances the evening atmosphere.'}
#
# Example 109:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=900x600 at 0x17FB1AD90>, 'text': 'The house is a two-story structure featuring a front porch with a gable roof, a single-car garage, and tidy landscaping.'}
#
# Example 110:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=719x480 at 0x17FB18150>, 'text': 'The house exhibits a modern Southwestern architectural style, featuring smooth stucco walls, flat roofs and desert landscaping accentuated by prominent large cacti.'}
#
# Example 111:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x480 at 0x17FB1B250>, 'text': 'The house features a Southwestern architectural style with stucco walls, a low-pitched roof, stone accents, and desert landscaping with cacti and gravel.'}
#
# Example 112:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=900x600 at 0x17FB1B1D0>, 'text': 'The house is a two-story structure with a modern facade, featuring multiple large windows, garages, and a small entryway. Notable elements include prominent gabled rooflines.'}
#
# Example 113:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x682 at 0x15828A250>, 'text': 'The facade features smooth, gray stucco walls, a dark front door, white-trimmed windows, modern horizontal wood fencing, and minimalistic landscaping with a small plant near the entrance.'}
#
# Example 114:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=767x511 at 0x17FB1BAD0>, 'text': 'The house features a Craftsman architectural style with a low-pitched roof, overhanging eaves, exposed rafters, and tapered columns supporting the front porch.'}
#
# Example 115:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x682 at 0x17FB1B1D0>, 'text': 'Charming two-story, modern suburban home features a symmetrical facade, manicured lawn with young trees, stone pathway, and a cozy front porch, exuding warmth and inviting curb appeal.'}
#
# Example 116:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x678 at 0x17FB1AD50>, 'text': 'The facade features beige stucco walls, arched doorways, terracotta roof tiles, wrought iron accents, and minimalistic exterior lighting. Decorated with small shrubs and neatly trimmed hedges.'}
#
# Example 117:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x683 at 0x17FB19D50>, 'text': 'The house is single-story with a front entrance porch, arched windows, and a small front garden. It features unique curved elements and stone steps leading to the entryway.'}
#
# Example 118:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x682 at 0x17FB19010>, 'text': 'Charming Spanish-style home features a stucco exterior, red tile roof, arched entryway, one-car garage, and a quaint front yard with mature tree and wrought-iron railing, inviting and unique.'}
#
# Example 119:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x682 at 0x17FB1A550>, 'text': 'The house exhibits the Victorian architectural style with intricate woodwork, gable roof, decorative trims, and pastel color palette, reflecting 19th-century design elements.'}
#
# Example 120:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x682 at 0x17FB1B090>, 'text': 'Two-story Mediterranean-style home featuring a stucco exterior, wrought iron balconies, tiled roof, lush landscaping, and a charming street lamp enhancing its curb appeal on the corner lot.'}
#
# Example 121:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x682 at 0x17FB19F50>, 'text': 'The house exhibits Victorian architectural style, distinguished by ornate detailing, steep gabled roofs, bay windows, and a prominent front porch.'}
#
# Example 122:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x480 at 0x17FB18150>, 'text': 'Contemporary desert home featuring a seamless single-story layout, xeriscaped yard, shaded facade, and an inviting entrance, blending modern design with natural surroundings for a harmonious aesthetic.'}
#
# Example 123:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x15851BF90>, 'text': 'The house exhibits Craftsman architectural style features, including a gabled roof, exposed rafters, and a spacious porch with wooden detailing.'}
#
# Example 124:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x682 at 0x17F828C10>, 'text': 'Modern two-story home with large arched windows, gabled roof, two-car garage, and minimalistic landscaping. Structurally open layout enhances natural light, creating a bright, airy living space.'}
#
# Example 125:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x682 at 0x1586D8190>, 'text': 'The house is a two-story structure with a front garage and covered area. It lacks balconies, terraces, or verandas.'}
#
# Example 126:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x684 at 0x17FB18150>, 'text': 'The exterior features beige horizontal siding, a bold red front door, white trim, and a white picket fence. The front porch includes decorative brackets and railings.'}
#
# Example 127:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=900x600 at 0x15851BE50>, 'text': 'This charming Colonial-style home features two stories, elegant gable roof, spacious front porch, attached garage, and a well-maintained garden, offering unique curb appeal and modern elegance.'}
#
# Example 128:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x683 at 0x17F82A810>, 'text': 'The house features a traditional suburban architectural style with a two-story structure, double garage, bay window, gable roof, and a combination of brick and siding exterior.'}
#
# Example 129:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427 at 0x15851BE50>, 'text': 'The facade features light blue siding, white trim, and large windows. It includes lush landscaping, a patio, and palm trees without visible decorative elements or lighting fixtures.'}
#
# Example 130:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1020x679 at 0x158233390>, 'text': 'This two-story house features a large backyard with a pool, multiple balconies, arched verandas, and Mediterranean-style architecture with stucco walls and red-tiled roofs.'}
#
# Example 131:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1020x680 at 0x1585181D0>, 'text': 'The facade features light peach vertical siding, white trim, a metal lamp, potted plants, decorative latticework, and a white railing. A brown fabric awning covers the entrance.'}
#
# Example 132:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1020x654 at 0x1585182D0>, 'text': 'Single-story house with attached garage, simple pitched roof, and a set of stairs leading up from the street. It features minimalistic design and is surrounded by natural landscaping.'}
#
# Example 133:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x480 at 0x158519D90>, 'text': 'The house showcases a contemporary Mediterranean style with stucco walls, a red-tiled roof, large glass windows, open arches, and an expansive outdoor living area with a pool.'}
#
# Example 134:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1318x756 at 0x1585182D0>, 'text': 'The facade features light brown horizontal siding, beige stone accents, and a grey shingled roof. Decorative elements include white trim, patio furniture, and a small wall-mounted light fixture.'}
#
# Example 135:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x600 at 0x15851A050>, 'text': 'This is a single-story house with a tiled roof, an arched entryway, a charming front door, and an attached garage, surrounded by lush greenery and a brick path.'}
#
# Example 136:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=750x498 at 0x15851A390>, 'text': 'This Spanish-style home features an intricate façade, clay tile roofing, lush gardens, a central fountain, arched entryway, and serene paths, offering an inviting and unique architectural charm.'}
#
# Example 137:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1020x680 at 0x15851AF90>, 'text': 'Single-story ranch-style house with a low-pitched roof, horizontal lines, large windows, and a simple, functional design, accentuated by a brick walkway and lush landscaping.'}
#
# Example 138:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x397 at 0x17FB1AD50>, 'text': 'The house is a single-story structure featuring a minimalist design, central vertical element, two balconies, and a mix of enclosed and open spaces.'}
#
# Example 139:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=638x360 at 0x15851BC90>, 'text': 'The facade features light beige walls, a dark shingled roof, white window trims, a vibrant red door, and simple landscaping. No visible decorative elements or lighting fixtures.'}
#
# Example 140:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1020x680 at 0x15851A1D0>, 'text': 'This house features a mid-20th century ranch-style design, with low-pitched rooflines, natural stone siding accents, and a simple, single-story layout.'}
#
# Example 141:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1020x683 at 0x17F8294D0>, 'text': 'This modern home features a sprawling layout, open-concept interior, extensive glass windows, a lush lawn, and a unique, curvaceous swimming pool overlooked by mountain views.'}
#
# Example 142:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=960x552 at 0x15851B910>, 'text': 'The house displays a modern suburban architectural style with a beige facade, gabled roofs, large windows, and attached garage, featuring clean lines and understated decorative elements.'}
#
# Example 143:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x424 at 0x15851A390>, 'text': 'Charming two-story Craftsman home with gable roofs, stone accents, spacious lawn, welcoming front porch, and brick-paver steps. Features open-plan design and elegant shutters, blending comfort with curb appeal.'}
#
# Example 144:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x480 at 0x158519610>, 'text': 'The facade features earthy stucco and stone materials, with warm beige and brown tones. Decorative lighting fixtures highlight the entrance, and stone accents add texture and visual interest.'}
#
# Example 145:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x664 at 0x15851A190>, 'text': 'This modern two-story stucco home features stone accents, a spacious driveway, arched porch, and manicured lawn, blending contemporary design with traditional elements and offering ample garage space.'}
#
# Example 146:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x683 at 0x15851A4D0>, 'text': 'The house features a modern suburban style, characterized by a simple, symmetrical façade, attached garage, steep gabled roof, and a blend of stucco and clapboard siding.'}
#
# Example 147:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x682 at 0x1585192D0>, 'text': 'Cream stucco walls with brown shutters and roof tiles, textured brick accent around the entrance, black decorative light fixtures, landscaping with greenery and bushes.'}
#
# Example 148:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x676 at 0x158519510>, 'text': 'This two-story house features a tiled roof, arched entryway, dual garage, and shuttered windows, providing a blend of modern and Mediterranean architectural elements.'}
#
# Example 149:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x558 at 0x1585194D0>, 'text': 'The house features a contemporary suburban architectural style, with clean lines, stucco walls, brick accents, gable roofs, and shuttered windows, creating a modern yet traditional look.'}
#
# Example 150:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x681 at 0x15851B310>, 'text': 'Modern two-story home featuring Mediterranean style, spacious driveway, three-car garage, manicured lawn, large windows, balconies, and green shutters. Unique blend of elegance and functionality.'}
#
# Example 151:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x947 at 0x15851BA90>, 'text': 'Two-story house with twin garages, arched doorway, and symmetrically placed windows. Features include white trims, a tiled roof, and a small front portico.'}
#
# Example 152:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x920 at 0x15851A390>, 'text': 'Stucco facade, beige and tan colors, red tile roof, arched windows, green shutters, decorative trim, twin exterior lanterns flanking garage, lush landscaping with palm trees.'}
#
# Example 153:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x158519410>, 'text': 'This two-story house features a three-car garage, a mix of stone and stucco exterior, and window shutters. It lacks balconies, terraces, or verandas.'}
#
# Example 154:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x684 at 0x158518650>, 'text': 'The facade features beige stucco, tan vertical siding panels, white trim, and a tan garage door. Decorative lighting fixtures flank the garage.'}
#
# Example 155:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x480 at 0x15851AF50>, 'text': 'This single-story house features a stucco exterior, arched entryway, and a garage. Unique architectural elements include a front archway and desert landscaping in the front yard.'}
#
# Example 156:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x680 at 0x15851BB10>, 'text': 'Modern Mediterranean-style home featuring two stories, arched entryway, terra-cotta roof tiles, manicured lawn, and attached double garage. Spacious layout with characterful exterior and contemporary finishes.'}
#
# Example 157:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x683 at 0x15851AF50>, 'text': 'This house features a Mediterranean architectural style, characterized by stucco walls, red clay tile roof, and arched entryway, promoting a warm, coastal appearance.'}
#
# Example 158:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x158518310>, 'text': 'The facade features light grey stucco with white trim, grey shutters, and paneled garage doors. Decorative elements include gable accents, column details, and lush landscaping. No lighting fixtures visible.'}
#
# Example 159:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x683 at 0x15851BB10>, 'text': 'This two-story house features an inviting front balcony, an attached garage, and a covered front veranda. The exterior combines stucco and stone finishes, enhancing its architectural appeal.'}
#
# Example 160:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x516 at 0x15851AD50>, 'text': 'Modern suburban style with a two-story structure, gabled rooflines, stucco exterior, and stone accents; featuring a covered porch and attached two-car garage.'}
#
# Example 161:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x15851B9D0>, 'text': 'This single-story modern-ranch home features a spacious three-car garage, manicured front garden with palm trees, stucco exterior with horizontal siding, and a charming front porch.'}
#
# Example 162:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x692 at 0x158519F50>, 'text': 'The house features two stories, a front balcony, dual garages, and a covered entrance porch, showcasing a cohesive, modern design with manicured lawns.'}
#
# Example 163:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x682 at 0x15851B550>, 'text': 'The facade features beige stucco, red shutters, and brick accents. Lighting includes a traditional lantern-style fixture. The garage doors and roof are tan, complementing the neutral color scheme.'}
#
# Example 164:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x1024 at 0x158518FD0>, 'text': 'The house is a two-story structure featuring a covered front porch, multiple windows, and a simple, modern architectural design.'}
#
# Example 165:
# ...
#
# Example 481:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x533 at 0x158518150>, 'text': 'The facade features light-colored stucco, beige garage doors, a tiled walkway, and a grey tile roof. There are columnar accents and warm exterior lighting fixtures.'}
#
# Example 482:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1020x573 at 0x17FB1A2D0>, 'text': 'Modern two-story home with a pitched roof, prominent arch windows, and attached two-car garage. Features a well-kept front lawn, stucco exterior, and a charming entrance with garden accents.'}
#
# Example 483:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1020x679 at 0x158518150>, 'text': 'The house features a modern suburban style with stucco walls, gabled roofs, large windows, and a well-manicured garden with brick steps leading to the entrance.'}
#
# Example 484:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x426 at 0x15851AAD0>, 'text': 'This two-story house features a wrap-around veranda, gabled roof, and large, front-facing windows, providing an inviting and spacious layout.'}
#
# Example 485:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x158518150>, 'text': 'The house features a simplistic, single-story ranch style with vinyl siding, a low-pitched roof, and red shutter accents, typical of rural American homes.'}
#
# Example 486:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x425 at 0x15851AAD0>, 'text': 'This charming home boasts a rustic architectural style with stone accents, a spacious two-story layout, manicured lawns, a balcony, and distinctively landscaped gardens, enhancing its unique curb appeal.'}
#
# Example 487:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x15851B910>, 'text': 'The house is a single-story structure with a spacious veranda, multiple gables, and an attached garage, featuring wide, covered patios.'}
#
# Example 488:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427 at 0x15851AAD0>, 'text': 'The facade features beige stucco walls, brown shingle roofing, and white trim. Decorative elements include circular wall art. White planters and minimalistic exterior lighting fixtures are present.'}
#
# Example 489:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427 at 0x15851B910>, 'text': 'This is a single-story house with a sloped roof, front veranda, and multiple windows providing ample natural light. The structure is simple, emphasizing functionality and openness.'}
#
# Example 490:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=580x435 at 0x158518B50>, 'text': 'The facade uses red brick and white siding with white framed windows, complemented by a small, modern garden. There is a simple lighting fixture under the roofline.'}
#
# Example 491:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=869x599 at 0x15851B910>, 'text': 'A Southwestern-style home with stucco exterior, clay tile roof, arched entryway, three-car garage, drought-tolerant landscaping, and a beautifully patterned pathway, featuring unique adobe aesthetic and rustic charm.'}
#
# Example 492:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=580x436 at 0x15851AC50>, 'text': 'The house is a two-story structure with a simple, rectangular design and no visible balconies, terraces, or verandas. A detached garage is situated to the side.'}
#
# Example 493:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=580x436 at 0x17FB1AA50>, 'text': 'The facade features red bricks and beige siding with green shutters. Decorative elements include white trim, a front porch with columns, a classic lantern lamp, and potted plants.'}
#
# Example 494:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x480 at 0x15851B090>, 'text': 'This house features a brick exterior, steep gable roofs, arched windows and doorways, embodying the traditional suburban American architectural style with a touch of contemporary elements.'}
#
# Example 495:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=580x436 at 0x17F8292D0>, 'text': 'Charming suburban home with traditional architectural style, featuring a brick façade, gabled roof, and attached garage. Manicured lawn, front porch, and flagpole enhance its curb appeal.'}
#
# Example 496:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=580x435 at 0x15851B090>, 'text': 'The facade features white vinyl siding, black shingles, and a bay window. Decorative elements include a small garden and shrubbery. A porch light fixture is situated near the entry door.'}
#
# Example 497:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=580x436 at 0x15851B790>, 'text': 'This two-story brick house features large arched windows, a three-car garage, and a prominent front door, with an attractive gable roof design and well-maintained landscaping.'}
#
# Example 498:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=580x435 at 0x15851B090>, 'text': 'This ranch-style home features a spacious rear deck, walk-out basement, large fenced backyard, built-in shed, and landscaped patio, offering functional indoor-outdoor living ideal for family life and entertaining.'}
#
# Example 499:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=580x436 at 0x158518150>, 'text': 'The house features a modern suburban architectural style, with brick exterior, symmetrical facade, large windows, and prominent gable roof lines.'}
#
# Example 500:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=580x436 at 0x15851AFD0>, 'text': 'Charming split-level home with modern colonial architecture, featuring a two-car garage, mature trees, and a sloping front yard, accentuated by unique dormer windows and a welcoming double-door entrance.'}
#
# Example 501:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x683 at 0x15851BED0>, 'text': 'The house features a traditional suburban architectural style with brick and siding exterior, prominent columns, and red shutters.'}
#
# Example 502:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x412 at 0x15851B090>, 'text': 'This is a single-story house with a spacious front veranda, arched windows, Mediterranean-style roof, and an entryway featuring a semi-circular portico. The desert landscaping enhances its unique architecture.'}
#
# Example 503:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x682 at 0x15851B290>, 'text': 'This house features a modern ranch-style architecture with clean lines, single-story layout, large windows, and an expansive lawn.'}
#
# Example 504:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=580x436 at 0x15851A810>, 'text': 'This charming ranch-style home features a symmetrical layout, brick and siding facade, large front porch, manicured lawn, and mature trees, blending classic design with modern comfort.'}
#
# Example 505:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=580x435 at 0x15851A910>, 'text': 'Single-story house with a brick exterior, gable roof, and a small covered porch. It features multiple windows adorned with shutters and a neatly landscaped garden.'}
#
# Example 506:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=580x436 at 0x158518150>, 'text': 'The exterior features light grey horizontal siding, white trims, and a red front porch. Decorative elements include white railings and a covered entryway. No visible lighting fixtures.'}
#
# Example 507:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x15851AFD0>, 'text': 'A charming suburban home with craftsman-style architecture, featuring large windows, a raised deck, lush landscaping, and unique multi-level outdoor living spaces amid verdant surroundings.'}
#
# Example 508:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x1585194D0>, 'text': 'The house features a modern suburban architectural style with symmetrical windows, vinyl siding, a gable roof, a front porch, and an attached two-car garage.'}
#
# Example 509:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=580x436 at 0x158519590>, 'text': 'The facade features yellow and white paint, brickwork, and columns. Decorative elements include planters and a hanging American flag. Lighting fixtures are black wall-mounted lanterns.'}
#
# Example 510:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x15851AED0>, 'text': 'The house is a two-story structure with a double garage, large windows, and a modest entryway. It features a balanced, symmetrical facade with simple architectural lines.'}
#
# Example 511:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x158518D10>, 'text': 'The house features beige vinyl siding, white trim, brown shutters, and a white garage door. Large windows and minimal decorative elements create a clean, classic look. No visible exterior lighting fixtures.'}
#
# Example 512:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427 at 0x1585183D0>, 'text': 'The house is a two-story structure with a split-level design, featuring bay windows and a dual entrance with a central staircase.'}
#
# Example 513:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=903x600 at 0x158518B50>, 'text': 'The facade features earth-toned stucco walls, terracotta roof tiles, wrought iron details, and a wooden door. Desert landscaping complements the design, with trees and cacti providing greenery.'}
#
# Example 514:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427 at 0x15851A8D0>, 'text': 'The facade features vertical beige siding, white-framed windows, and reddish-brown brick accents. Greenery is used decoratively, with a traditional lantern-style light fixture by the walkway.'}
#
# Example 515:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x683 at 0x158518B50>, 'text': 'Single-story house with a pointed roof, solar panels, and a modest front porch with seating. The architecture is simple, featuring wood siding and large windows.'}
#
# Example 516:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x684 at 0x15851BA10>, 'text': 'Charming Spanish-style home with tile roof, manicured lawn, cozy porch, attached two-car garage, lush landscaping, inviting entryway, and serene surroundings, creating an elegant and peaceful living space.'}
#
# Example 517:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x764 at 0x15851B250>, 'text': 'The house features a rustic architectural style with stone exterior walls, a gabled roof, and a covered front porch.'}
#
# Example 518:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x683 at 0x15851AB90>, 'text': 'Single-story home with a tiled roof, an attached garage, covered porch entry, and landscaped front yard. Situated on a hillside, featuring multiple large windows and lush surroundings.'}
#
# Example 519:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x683 at 0x158518450>, 'text': 'The facade features stucco walls in light brown, white trim, and a red-tiled roof, complemented by wooden pergola beams and black outdoor lighting fixtures.'}
#
# Example 520:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x680 at 0x158518410>, 'text': 'This house features a Mediterranean architectural style with stucco walls, red-tiled roof, arched openings, and clean lines.'}
#
# Example 521:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x680 at 0x15851AF90>, 'text': 'Mediterranean-style villa provides an inviting layout with large windows, arched doorways, lush landscaped garden, palm trees, and elegant exterior lighting. Unique hillside setting enhances natural beauty.'}
#
# Example 522:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x682 at 0x158518050>, 'text': 'The house features modern ranch-style architecture with a low-pitched roof, stucco exterior, stone accents, large windows, and an open entry courtyard.'}
#
# Example 523:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=666x442 at 0x15851BAD0>, 'text': 'This two-story contemporary home features a three-car garage, large windows, and a modest front yard. It includes an expansive driveway, low-maintenance landscaping, and scenic natural surroundings for extra charm.'}
#
# Example 524:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=900x600 at 0x15851BED0>, 'text': 'This single-story house features a flat roof, stucco exterior with stone accents, a prominent entryway, and multiple small verandas. It has a desert landscape.'}
#
# Example 525:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x396 at 0x15851A310>, 'text': 'Charming ranch-style home with a spacious front porch, detached garage, and mountain backdrop. Features include mature trees, a manicured yard, and a serene, remote setting offering privacy and natural beauty.'}
#
# Example 526:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x680 at 0x15851BED0>, 'text': 'The house features Mediterranean architecture with stucco walls, red-tiled roof, expansive windows, and an open courtyard design, blending indoor and outdoor living spaces harmoniously.'}
#
# Example 527:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x680 at 0x158518D10>, 'text': 'The facade features beige stucco walls, terra cotta roof tiles, white trim windows, decorative wall hangings, and a central fountain. Lighting fixtures include wall-mounted lanterns.'}
#
# Example 528:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x158519350>, 'text': 'The house is a two-story structure with a metal roof, featuring a large front veranda supported by pillars, and an extended porch to one side.'}
#
# Example 529:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x683 at 0x15851A310>, 'text': 'The house exhibits a contemporary ranch-style architecture with a simplistic, single-story design, prominent overhanging eaves, and a functional, unadorned exterior.'}
#
# Example 530:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x682 at 0x17FB18DD0>, 'text': '"Single-story mobile home featuring a small front porch, carport, and minimalist outdoor seating area, offering a cozy, practical living space."'}
#
# Example 531:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x425 at 0x17F82B5D0>, 'text': 'The house is single-story with a separate garage, featuring a slanted roof, front porch, and landscaped entrance, offering a simple yet elegant architectural design.'}
#
# Example 532:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x680 at 0x158518710>, 'text': 'The facade features beige stucco, tiled roof, arched entryway with stone columns, white-framed windows, and subtle exterior lighting fixtures. Decorative plants and trim details enhance the aesthetic.'}
#
# Example 533:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x680 at 0x158764190>, 'text': 'This is a two-story house with a tiled roof, prominent front gable, large windows, and an attached garage, featuring a clean, charming exterior.'}
#
# Example 534:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1020x764 at 0x158767710>, 'text': 'The facade features beige vertical siding, brown shingle roofing, white trim, and decorative lantern-style lighting fixtures. Includes white framed windows and tan garage door with decorative arches.'}
#
# Example 535:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=900x600 at 0x158764F90>, 'text': 'The facade features stucco in warm earthy tones, terracotta roofing, arched windows, wrought iron accents, brick driveway, and decorative lighting fixtures, accentuating a charming southwestern style.'}
