# %%
from gen_descriptions import generate_descriptions

# Example usage
generate_descriptions(num_images=10, view_images=True)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Description: Modern two-story home with a charming porch, spacious dual garages, stucco exterior, tiled roof, and manicured lawn. Highlights include layered roofline, prominent eaves, and inviting outdoor veranda.
# Description: This house features a contemporary suburban architectural style with a stucco exterior, gabled roofs, and a mix of stone accents on the front porch columns.
# Description: This two-story house features a three-car garage, a covered front porch, and a well-maintained lawn, creating an inviting exterior.
# Description: The facade features beige stucco with white trim, stone accent pillars, and a reddish-brown shingle roof; includes light fixtures by the garage and front door.
# Description: Southwestern-style home with brick facade, pitched roof, and arched entry. Features xeriscaped garden, American flagpole, and ambient night lighting, creating a serene desert oasis.
# ...
